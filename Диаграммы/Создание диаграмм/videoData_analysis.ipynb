# %%
import h5py as h5
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import json

# %%
filePath = 'C:\Users\Danya\Desktop\diploma\Диаграммы\Создание диаграмм'

with h5.File(filePath, 'r') as file:
    data = file['class']
    cls = data[:]
    data = file['n_webm']
    n_webm = data[:]
    data = file['n_mp4']
    n_mp4 = data[:]
    data = file['amout_video']
    am = data[:]
    data = file['time']
    time = data[:]
    data = file['size']
    size = data[:]
    
df = pd.DataFrame( 
        {'class' : cls, 
         'n_webn' : n_webm, 
         'n_mp4' : n_mp4,
         'amount' : am, 'time' : time, 'size' : size})
df
# Out:
#     class  n_webn   n_mp4  amount          time           size
# 0     1.0    20.0   397.0   417.0  1.499217e+05   11357.133186
# 1    10.0    86.0  1232.0  1318.0  2.541518e+05   21872.789921
# 2    52.0   108.0  1394.0  1502.0  3.229082e+05   22391.821556
# 3    54.0    38.0   390.0   428.0  1.187916e+05    8481.205723
# 4    77.0    74.0  1811.0  1885.0  3.300673e+05   27124.325795
# 5    90.0   186.0  1779.0  1965.0  1.807801e+05   15479.236642
# 6    95.0   133.0  1645.0  1778.0  5.974055e+05   53619.074027
# 7   166.0    88.0  1628.0  1716.0  1.111585e+06  103257.977710
# 8   219.0   121.0  1792.0  1913.0  2.770972e+05   22500.137419
# 9   278.0   122.0  1808.0  1930.0  3.292571e+05   26385.524751
# 10  303.0    84.0  1336.0  1420.0  4.021953e+05   36543.328551
# 11  310.0    73.0   861.0   934.0  1.423170e+05    9857.000839
# 12  326.0    89.0  1373.0  1462.0  2.576436e+05   21525.429715
# 13  333.0   102.0  1838.0  1940.0  5.273602e+05   48428.102133
# ...

# %%
size_ = list(df['size'] / 1024)
size_

first = [size_[0], size_[7], size_[2], size_[11], size_[15], size_[17], size_[14], size_[6],size_[3], size_[9]]
second = [size_[19], size_[4], size_[18], size_[10], size_[16], size_[13], size_[8], size_[5], size_[12], size_[1]]

# %%
names = ['Boxing \n Sumo', 'Biathlon \n Skiing', 'Judo\n Karate', 'Street racing \n Offroad-racing', 
         'Volleyball \n Basketball', 'Arena football \n Team handball', 'Hockey Roller skating',
                'Water polo \n Butterfly stroke', 'Tennis \n Beach tennis', 'Motorcycle speedway \n Bicycle']

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import datetime as dt
import sys

# %%
dpi = 70
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 384 / dpi) )
mpl.rcParams.update({'font.size': 10})

plt.title('Диграмма размера видео по каждому классу. Тренировочная выборка.')

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(names))

plt.bar([x + 0.05 for x in xs], first,
        width = 0.2, color = 'red', alpha = 0.7,
        zorder = 2)

plt.bar([x + 0.3 for x in xs], second,
        width = 0.2, color = 'blue', alpha = 0.7,
        zorder = 2)

plt.xticks(xs, names)

fig.autofmt_xdate(rotation = 50)

plt.xlabel('Классы')
plt.ylabel('Gb')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %%
dpi = 70
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 384 / dpi) )
mpl.rcParams.update({'font.size': 10})

plt.title('Диграмма размера видео по каждому классу. Тренировочная выборка.')

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)

xs = range(len(labels))

plt.bar([x + 0.05 for x in xs], df['size'] / 1024,
        width = 0.2, color = 'red', alpha = 0.7, label = 'Размер видео',
        zorder = 2)

plt.xticks(xs, labels)

fig.autofmt_xdate(rotation = 25)

plt.legend(loc='upper right')

plt.xlabel('Классы')
plt.ylabel('Gb')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %%
dpi = 70
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 384 / dpi) )
mpl.rcParams.update({'font.size': 10})

plt.title('Диграмма длительности видео по каждому классу. Тренировочная выборка.')

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)
plt.ylabel('Сек')
plt.xlabel('Классы')

xs = range(len(labels))

plt.bar([x for x in xs], df['time'],
        width = 0.2, color = 'blue', alpha = 0.7, label = 'Время',
        zorder = 2)

plt.xticks(xs, labels)

fig.autofmt_xdate(rotation = 25)

plt.legend(loc='upper right')
plt.show()
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys

# %%
dpi = 70
fig = plt.figure(dpi = dpi, figsize = (1024 / dpi, 384 / dpi) )
mpl.rcParams.update({'font.size': 10})

plt.title('Диграмма количсетва видео по каждому классу. Тренировочная выборка.')

ax = plt.axes()
ax.yaxis.grid(True, zorder = 1)
plt.ylabel('ед.')
plt.xlabel('Классы')

xs = range(len(labels))

plt.bar([x for x in xs], df['amount'],
        width = 0.2, color = 'green', alpha = 0.7, label = 'Количество видео файлов',
        zorder = 2)

plt.xticks(xs, labels)

fig.autofmt_xdate(rotation = 25)

plt.legend(loc='upper right')
# Out:
# D:\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   import sys
